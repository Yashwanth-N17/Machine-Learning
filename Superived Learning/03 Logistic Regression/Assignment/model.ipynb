# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("turnover.csv", encoding="latin1")

# %%
df.head()
# Out:
#         stag  event gender   age         industry  profession      traffic  \
# 0   7.030801      1      m  35.0            Banks          HR  rabrecNErab
# 1  22.965092      1      m  33.0            Banks          HR        empjs
# 2  15.934292      1      f  35.0  PowerGeneration          HR  rabrecNErab
# 3  15.934292      1      f  35.0  PowerGeneration          HR  rabrecNErab
# 4   8.410678      1      m  32.0           Retail  Commercial        youjs
#
#   coach head_gender greywage  way  extraversion  independ  selfcontrol  \
# 0    no           f    white  bus           6.2       4.1          5.7
# 1    no           m    white  bus           6.2       4.1          5.7
# 2    no           m    white  bus           6.2       6.2          2.6
# 3    no           m    white  bus           5.4       7.6          4.9
# 4   yes           f    white  bus           3.0       4.1          8.0
#
#    anxiety  novator
# 0      7.1      8.3
# 1      7.1      8.3
# 2      4.8      8.3
# ...

# %%
data = df
data["gender"] = data["gender"].map({"f":0,"m":1})

# %%
data.sample(10)
# Out:
#            stag  event  gender   age     industry profession      traffic  \
# 812   38.702259      0       0  33.0       Retail         HR      referal
# 40    13.075975      1       0  21.0          etc         HR        empjs
# 1118   6.800821      0       1  25.0  manufacture         HR      friends
# 746   20.303901      0       0  45.0        State         HR  rabrecNErab
# 1093  20.468172      0       0  31.0      Consult         HR        youjs
# 683   21.486653      0       0  27.0       Retail         HR        empjs
# 280    1.642710      1       0  44.0          etc         HR        youjs
# 618   36.008214      0       0  45.0    transport         HR     recNErab
# 112   14.850103      1       1  25.0  manufacture         HR        empjs
# 877    5.585216      0       0  32.0           IT         HR        youjs
#
#         coach head_gender greywage  way  extraversion  independ  selfcontrol  \
# ...
